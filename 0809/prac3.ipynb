# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為何是藍色的"
)

print(interaction.output_text)
# Out:
# 天空呈現藍色，主要是因為一個物理現象，叫做**「瑞利散射」（Rayleigh scattering）**。這個過程可以拆解為以下幾個簡單的步驟來理解：
#
# ### 1. 陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有顏色的光混合而成的。
# *   每種顏色的光都有不同的**波長**。
# *   **紅光**和**黃光**的波長較長，像大波浪一樣，穿透力強。
# *   **藍光**和**紫光**的波長較短，像小碎步一樣，容易被干擾。
#
# ### 2. 大氣層的「阻擋」
# 地球被厚厚的大氣層包圍，空氣中充滿了極小的氮氣（$N_2$）和氧氣（$O_2$）等氣體分子。
# 當陽光穿過大氣層時，波長較長的紅光、黃光可以像沒事一樣，直接穿過這些微小的氣體分子直達地面。
#
# ### 3. 藍光的「散射」
# 然而，波長較短的**藍光**遇到這些微小的氣體分子時，就會像彈珠碰到障礙物一樣，**向四面八方彈射開來**。這種現象就是「散射」。當我們抬頭看天空時，這些在空氣中被到處亂彈的藍光進入了我們的眼睛，所以天空看起來就是藍色的。
#
# ---
#
# ### 常見疑問：為什麼天空不是「紫色」的？
# 紫光的波長比藍光還要短，照理說紫光的散射應該更嚴重，那天空為什麼不是紫色的？這有兩個主要原因：
#
# 1.  **太陽光本身的比例**：太陽發射的光線中，藍光的強度本來就比紫光強很多。
# 2.  **人類眼睛的構造**：人類眼睛的視網膜上有三種辨色細胞（錐狀細胞），分別對紅、綠、藍色最敏感。我們的眼睛對藍光非常敏感，但對紫光的敏感度很低。因此，大腦會自動把天空的主色調解釋為藍色。
#
# ### 額外知識：為什麼夕陽是紅色的？
# 傍晚時，太陽西斜，陽光需要穿過**更厚**的大氣層才能到達我們的眼睛。在這段長途旅程中，絕大多數的藍光在半路就已經被散射光了，只剩下穿透力最強的**紅光、橙光**能成功到達我們的眼睛，所以夕陽和晚霞才會呈現美麗的紅色和橙色。
